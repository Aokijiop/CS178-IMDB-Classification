# %%
# Importing modules
import numpy as np
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
from sklearn.datasets import fetch_openml
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import learning_curve
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from datasets import load_dataset
from gensim.models import Word2Vec
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from typing import Tuple
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from tabulate import tabulate
from sklearn.metrics import precision_score, recall_score, classification_report

import warnings
warnings.filterwarnings('ignore')

# Fix the random seed for reproducibility
# !! Important !! : do not change this
seed = 1234
np.random.seed(seed)

# %%
# Load dataset once
imdb_dataset = load_dataset("imdb")

# %%
# Preprocess the data
def preprocess(text):
    return text.lower().split()

train_sentences = [preprocess(text) for text in imdb_dataset['train']['text']]
test_sentences = [preprocess(text) for text in imdb_dataset['test']['text']]

# Train Word2Vec model
w2v_model = Word2Vec(sentences=train_sentences, vector_size=100, window=5, min_count=1, workers=4)

# Vectorize the sentences
def vectorize_sentences(sentences, model, vector_size):
    vectors = []
    for sentence in sentences:
        sentence_vec = np.zeros(vector_size)
        for word in sentence:
            if word in model.wv:
                sentence_vec += model.wv[word]
        vectors.append(sentence_vec / len(sentence))
    return np.array(vectors)

X_train = vectorize_sentences(train_sentences, w2v_model, 100)
X_test = vectorize_sentences(test_sentences, w2v_model, 100)

# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Inspect the shape of the transformed data
print(f"Train data shape: {X_train.shape}")
print(f"Test data shape: {X_test.shape}")
# Out:
# Train data shape: (25000, 100)
# Test data shape: (25000, 100)

# %%
# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Extract labels
y_train = imdb_dataset['train']['label']
y_test = imdb_dataset['test']['label']

# %%
def evaluate_model(n_estimators, max_depth, max_features):
    classifier = RandomForestClassifier(
        n_estimators=n_estimators, 
        max_depth=max_depth, 
        max_features=max_features, 
        random_state=seed
    )
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

# Parameters to test
n_estimators_options = [100, 200, 300]
max_depth_options = [None, 10, 20]
max_features_options = ['log2', 'sqrt']

results = []

# Test different configurations
for n_estimators in n_estimators_options:
    for max_depth in max_depth_options:
        for max_features in max_features_options:
            acc = evaluate_model(n_estimators, max_depth, max_features)
            results.append((n_estimators, max_depth, max_features, acc))

# Sort results by accuracy
results.sort(key=lambda x: x[3], reverse=True)

# %%
# Create a table showing the accuracy of the different hyperparameters being tweaked
print(tabulate(results, headers=["n_estimators", "max_depth", "max_features", "Accuracy"]))
# Out:
#   n_estimators    max_depth  max_features      Accuracy
# --------------  -----------  --------------  ----------
#            300               sqrt               0.72712
#            200               sqrt               0.727
#            300           20  sqrt               0.72676
#            300               log2               0.72612
#            200           20  sqrt               0.7258
#            200               log2               0.7252
#            300           20  log2               0.72484
#            200           20  log2               0.72436
#            100           20  sqrt               0.72192
#            100               sqrt               0.72132
#            100               log2               0.7196
#            100           20  log2               0.71852
#            300           10  sqrt               0.7146
#            200           10  sqrt               0.71348
#            300           10  log2               0.71236
#            100           10  sqrt               0.71188
#            200           10  log2               0.71168
#            100           10  log2               0.70912

# %%
# Generate the confusion matrix

classifier = RandomForestClassifier(n_estimators=300, max_depth=None, max_features='sqrt', random_state=seed)

classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Accuracy score for more optimized random forest:", acc)


conf_matrix = confusion_matrix(y_test, y_pred)

# Plot using seaborn for better visualization
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap="Blues", xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy score for more optimized random forest: 0.72496

# %%
# For a binary classification, calculate overall precision and recall
precision = precision_score(y_test, y_pred, average='binary')
recall = recall_score(y_test, y_pred, average='binary')

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")

# For multi-class classification, get precision and recall for each class
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 # For a binary classification, calculate overall precision and recall
#       2 precision = precision_score(y_test, y_pred, average='binary')
# ----> 3 recall = recall_score(y_test, y_pred_optimized, average='binary')
#       5 print(f"Precision: {precision:.2f}")
#       6 print(f"Recall: {recall:.2f}")
#
# NameError: name 'y_pred_optimized' is not defined

# %%
# Generate the training set sizes and learning curve data
train_sizes, train_scores, validation_scores = learning_curve(
    estimator=classifier,
    X=X_train,
    y=y_train,
    train_sizes=np.linspace(0.1, 1.0, 10),
    cv=5,
    scoring='accuracy',
    n_jobs=-1  # Use all computer cores
)

# Calculate mean and standard deviation for training set scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Calculate mean and standard deviation for validation set scores
validation_mean = np.mean(validation_scores, axis=1)
validation_std = np.std(validation_scores, axis=1)

# Plot the learning curve
plt.figure(figsize=(8, 5))
plt.plot(train_sizes, train_mean, label='Training score', color='blue', marker='o')
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color='blue', alpha=0.15)

plt.plot(train_sizes, validation_mean, label='Validation score', color='green', marker='o')
plt.fill_between(train_sizes, validation_mean - validation_std, validation_mean + validation_std, color='green', alpha=0.15)

plt.title('Learning Curve for Random Forest Classifier')
plt.xlabel('Training Data Size')
plt.ylabel('Accuracy')
plt.legend(loc='best')  # Ensure this line is present to show the legend
plt.grid(True)
plt.show()

# %%
# Now attempting to find best params with grid_search

param_grid = {
    'n_estimators': [100, 200, 300],  # More or fewer trees
    'max_depth': [None, 10, 20, 30],  # None means no limit
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4]     # Minimum number of samples required to be at a leaf node
}

grid_search = GridSearchCV(classifier, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)  # X_train and y_train need to be predefined with your data

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))

# %%
# Now we try with the best params available via gridsearch

optimized_classifier = RandomForestClassifier(**grid_search.best_params_) # dict unpacked

optimized_classifier.fit(X_train, y_train)

# Predict on the test data
y_pred_optimized = optimized_classifier.predict(X_test)

# Calculate the accuracy
accuracy_optimized = accuracy_score(y_test, y_pred_optimized)

print(f"Grid Search Accuracy: {accuracy_optimized:.4f}")
